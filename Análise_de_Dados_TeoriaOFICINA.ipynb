# %% [markdown]
# <a href="https://colab.research.google.com/github/helenksouza/Data-Science/blob/main/An%C3%A1lise_de_Dados_TeoriaOFICINA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# *  https://basedosdados.org/
#
# *   http://archive.ics.uci.edu/ml/index.php
#
# * https://www.kaggle.com/datasets
#
# * https://en.wikipedia.org/wiki/List_of...
#
# * https://www.reddit.com/r/datasets/
#
# * http://dataporta
#
# * ls.org/search https://registry.opendata.aws/
#
# * https://crawdad.org/
#
# * https://arxiv.org/
#
# * https://ces.ibge.gov.br/base-de-dados
#
# * https://www.ibge.gov.br/indicadores
#
# * https://queimadas.dgi.inpe.br/queimad...

# %%
import io
import pandas as pd
import requests 
import sys
import tweepy as tw

from bs4 import BeautifulSoup
from google.colab import files

# !pip install PyPDF2
import PyPDF2

print ('Pacotes carregados!')
# Out:
# ...
#      |████████████████████████████████| 77 kB 4.1 MB/s
# ...
#   Created wheel for PyPDF2: filename=PyPDF2-1.26.0-py3-none-any.whl size=61101 sha256=0b257a25646a42d87131dc4afd30fe6025b6345bb98fe2c97ac18a4f61db4a95
#   Stored in directory: /root/.cache/pip/wheels/80/1a/24/648467ade3a77ed20f35cfd2badd32134e96dd25ca811e64b3
# Successfully built PyPDF2
# ...
# Pacotes carregados!

# %% [markdown]
# ## Formatos de Dados para Data Science

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# > Primeira linha geralmente vem com nome dos campos.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **METADADOS**: dados adicionais que descrevem dados que estou vendo(dados iniciais).
#
# > área(m²)

# %% [markdown]
# XLSX mais rico.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Pickle: pode esvrever qq  coisa
# > CSV: escreve apenas texto
#
# Feather: velocidade em escrita
# > leitura 80x mais rápido

# %% [markdown]
# ## Usando uma API(Application Programming Interface)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
