# %% [markdown]
# <a href="https://colab.research.google.com/github/helenksouza/Data-Science/blob/main/request.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
### K: Adaptado de Daniel Bezerra (https://github.com/danielbnbezerra).
from bs4 import BeautifulSoup
import requests 
import sys

URL = 'https://www.gov.br/anp/pt-br/centrais-de-conteudo/dados-estatisticos'
OIL_DATA_LOCATION = 'https://www.gov.br/anp/pt-br/centrais-de-conteudo/dados-estatisticos/de/ppgn/pp/'

html_text = requests.get(URL).text
#print (html_text)

soup = BeautifulSoup(html_text, 'lxml')
general_content = soup.find_all('a')

#print (general_content)

oil_content_links = ['']
for content in general_content:
    link = content['href']
    if link.startswith(OIL_DATA_LOCATION):
        oil_content_links.append(link)

for link in oil_content_links:
    print (link)
    # !wget $link -P "/content/drive/My Drive/"
# Out:
# wget: missing URL
# Usage: wget [OPTION]... [URL]...
#
# Try `wget --help' for more options.
# https://www.gov.br/anp/pt-br/centrais-de-conteudo/dados-estatisticos/de/ppgn/pp/producao-por-pocos.zip
# --2021-11-15 23:06:11--  https://www.gov.br/anp/pt-br/centrais-de-conteudo/dados-estatisticos/de/ppgn/pp/producao-por-pocos.zip
# Resolving www.gov.br (www.gov.br)... 161.148.164.31
# Connecting to www.gov.br (www.gov.br)|161.148.164.31|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 25130044 (24M) [application/zip]
# Saving to: ‘/content/drive/My Drive/producao-por-pocos.zip’
#
# producao-por-pocos.   4%[                    ]   1.01M   528KB/s               ^C
# https://www.gov.br/anp/pt-br/centrais-de-conteudo/dados-estatisticos/de/ppgn/pp/producao-pocos-2020.zip
# --2021-11-15 23:06:14--  https://www.gov.br/anp/pt-br/centrais-de-conteudo/dados-estatisticos/de/ppgn/pp/producao-pocos-2020.zip
# Resolving www.gov.br (www.gov.br)... 161.148.164.31
# Connecting to www.gov.br (www.gov.br)|161.148.164.31|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 31398653 (30M) [application/zip]
# Saving to: ‘/content/drive/My Drive/producao-pocos-2020.zip’
#
# producao-pocos-2020 100%[===================>]  29.94M   825KB/s    in 40s
#
# 2021-11-15 23:06:54 (774 KB/s) - ‘/content/drive/My Drive/producao-pocos-2020.zip’ saved [31398653/31398653]
#
# https://www.gov.br/anp/pt-br/centrais-de-conteudo/dados-estatisticos/de/ppgn/pp/producao-pocos-2019.zip
# --2021-11-15 23:06:55--  https://www.gov.br/anp/pt-br/centrais-de-conteudo/dados-estatisticos/de/ppgn/pp/producao-pocos-2019.zip
# Resolving www.gov.br (www.gov.br)... 161.148.164.31
# Connecting to www.gov.br (www.gov.br)|161.148.164.31|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 33388379 (32M) [application/zip]
# Saving to: ‘/content/drive/My Drive/producao-pocos-2019.zip’
#
# producao-pocos-2019 100%[===================>]  31.84M   802KB/s    in 42s
#
# 2021-11-15 23:07:37 (780 KB/s) - ‘/content/drive/My Drive/producao-pocos-2019.zip’ saved [33388379/33388379]
#
# https://www.gov.br/anp/pt-br/centrais-de-conteudo/dados-estatisticos/de/ppgn/pp/producao-pocos-2018.zip
# --2021-11-15 23:07:37--  https://www.gov.br/anp/pt-br/centrais-de-conteudo/dados-estatisticos/de/ppgn/pp/producao-pocos-2018.zip
# Resolving www.gov.br (www.gov.br)... 161.148.164.31
# Connecting to www.gov.br (www.gov.br)|161.148.164.31|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 32443266 (31M) [application/zip]
# Saving to: ‘/content/drive/My Drive/producao-pocos-2018.zip’
#
# producao-pocos-2018  72%[=============>      ]  22.51M   790KB/s    eta 11s    ^C
# https://www.gov.br/anp/pt-br/centrais-de-conteudo/dados-estatisticos/de/ppgn/pp/producao-pocos-2017.zip
# --2021-11-15 23:08:08--  https://www.gov.br/anp/pt-br/centrais-de-conteudo/dados-estatisticos/de/ppgn/pp/producao-pocos-2017.zip
# Resolving www.gov.br (www.gov.br)... 161.148.164.31
# Connecting to www.gov.br (www.gov.br)|161.148.164.31|:443... connected.
# HTTP request sent, awaiting response... ^C
# https://www.gov.br/anp/pt-br/centrais-de-conteudo/dados-estatisticos/de/ppgn/pp/producao-pocos-2016.zip
# --2021-11-15 23:08:09--  https://www.gov.br/anp/pt-br/centrais-de-conteudo/dados-estatisticos/de/ppgn/pp/producao-pocos-2016.zip
# Resolving www.gov.br (www.gov.br)... 161.148.164.31
# Connecting to www.gov.br (www.gov.br)|161.148.164.31|:443... connected.
# ^C
# https://www.gov.br/anp/pt-br/centrais-de-conteudo/dados-estatisticos/de/ppgn/pp/producao-pocos-2015.zip
# --2021-11-15 23:08:10--  https://www.gov.br/anp/pt-br/centrais-de-conteudo/dados-estatisticos/de/ppgn/pp/producao-pocos-2015.zip
# Resolving www.gov.br (www.gov.br)... 161.148.164.31
# Connecting to www.gov.br (www.gov.br)|161.148.164.31|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 40144305 (38M) [application/zip]
# Saving to: ‘/content/drive/My Drive/producao-pocos-2015.zip’
#
# producao-pocos-2015  13%[=>                  ]   5.10M   785KB/s    eta 46s    ^C
# https://www.gov.br/anp/pt-br/centrais-de-conteudo/dados-estatisticos/de/ppgn/pp/producao-pocos-2014.zip
# --2021-11-15 23:08:18--  https://www.gov.br/anp/pt-br/centrais-de-conteudo/dados-estatisticos/de/ppgn/pp/producao-pocos-2014.zip
# Resolving www.gov.br (www.gov.br)... 161.148.164.31
# Connecting to www.gov.br (www.gov.br)|161.148.164.31|:443... ^C
# https://www.gov.br/anp/pt-br/centrais-de-conteudo/dados-estatisticos/de/ppgn/pp/producao-pocos-2013.zip
# --2021-11-15 23:08:18--  https://www.gov.br/anp/pt-br/centrais-de-conteudo/dados-estatisticos/de/ppgn/pp/producao-pocos-2013.zip
# Resolving www.gov.br (www.gov.br)... 161.148.164.31
# Connecting to www.gov.br (www.gov.br)|161.148.164.31|:443... connected.
# HTTP request sent, awaiting response... ^C
# https://www.gov.br/anp/pt-br/centrais-de-conteudo/dados-estatisticos/de/ppgn/pp/producao-pocos-2012.zip
# --2021-11-15 23:08:19--  https://www.gov.br/anp/pt-br/centrais-de-conteudo/dados-estatisticos/de/ppgn/pp/producao-pocos-2012.zip
# Resolving www.gov.br (www.gov.br)... 161.148.164.31
# Connecting to www.gov.br (www.gov.br)|161.148.164.31|:443... connected.
# HTTP request sent, awaiting response... ^C
# https://www.gov.br/anp/pt-br/centrais-de-conteudo/dados-estatisticos/de/ppgn/pp/producao-pocos-2011.zip
# --2021-11-15 23:08:20--  https://www.gov.br/anp/pt-br/centrais-de-conteudo/dados-estatisticos/de/ppgn/pp/producao-pocos-2011.zip
# Resolving www.gov.br (www.gov.br)... 161.148.164.31
# Connecting to www.gov.br (www.gov.br)|161.148.164.31|:443... ^C
# https://www.gov.br/anp/pt-br/centrais-de-conteudo/dados-estatisticos/de/ppgn/pp/producao-pocos-2010.zip
# --2021-11-15 23:08:20--  https://www.gov.br/anp/pt-br/centrais-de-conteudo/dados-estatisticos/de/ppgn/pp/producao-pocos-2010.zip
# Resolving www.gov.br (www.gov.br)... ^C
# https://www.gov.br/anp/pt-br/centrais-de-conteudo/dados-estatisticos/de/ppgn/pp/producao-pocos-2009.zip
# --2021-11-15 23:08:20--  https://www.gov.br/anp/pt-br/centrais-de-conteudo/dados-estatisticos/de/ppgn/pp/producao-pocos-2009.zip
# Resolving www.gov.br (www.gov.br)... 161.148.164.31
# Connecting to www.gov.br (www.gov.br)|161.148.164.31|:443... connected.
# HTTP request sent, awaiting response... ^C
# https://www.gov.br/anp/pt-br/centrais-de-conteudo/dados-estatisticos/de/ppgn/pp/producao-pocos-2008.zip
# --2021-11-15 23:08:21--  https://www.gov.br/anp/pt-br/centrais-de-conteudo/dados-estatisticos/de/ppgn/pp/producao-pocos-2008.zip
# Resolving www.gov.br (www.gov.br)... 161.148.164.31
# Connecting to www.gov.br (www.gov.br)|161.148.164.31|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13646967 (13M) [application/zip]
# Saving to: ‘/content/drive/My Drive/producao-pocos-2008.zip’
#
# producao-pocos-2008   4%[                    ] 627.50K   645KB/s               ^C
# https://www.gov.br/anp/pt-br/centrais-de-conteudo/dados-estatisticos/de/ppgn/pp/producao-pocos-2007.zip
# --2021-11-15 23:08:23--  https://www.gov.br/anp/pt-br/centrais-de-conteudo/dados-estatisticos/de/ppgn/pp/producao-pocos-2007.zip
# Resolving www.gov.br (www.gov.br)... 161.148.164.31
# Connecting to www.gov.br (www.gov.br)|161.148.164.31|:443... connected.
# ^C
# https://www.gov.br/anp/pt-br/centrais-de-conteudo/dados-estatisticos/de/ppgn/pp/producao-pocos-2006.zip
# ^C
# https://www.gov.br/anp/pt-br/centrais-de-conteudo/dados-estatisticos/de/ppgn/pp/producao-pocos-2005.zip
# --2021-11-15 23:08:24--  https://www.gov.br/anp/pt-br/centrais-de-conteudo/dados-estatisticos/de/ppgn/pp/producao-pocos-2005.zip
# Resolving www.gov.br (www.gov.br)... 161.148.164.31
# Connecting to www.gov.br (www.gov.br)|161.148.164.31|:443... connected.
# HTTP request sent, awaiting response... ^C
